# %%
import os

print("Python is searching in:", os.getcwd())
print("Files available there:", os.listdir())
# Out:
# Python is searching in: c:\Users\hp\Desktop\internship\project\database
# Files available there: ['database_connection.py', 'dump.ipynb', 'loading_pipeline.py', 'schemas.py', '__pycache__']

# %%
import pandas as pd

PURCHASE_FILE = "../Purchases List Report.xls"
STOCK_FILE    = "../Stock Value Report.xls"
ISSUANCE_FILE = "../Issuance Detail Report.xls"
IMPORT_FILE = "../Import Status Sheet-2026-02 July.xlsx"

purchase_df = pd.read_excel(PURCHASE_FILE)
stock_df = pd.read_excel(STOCK_FILE)
issuance_df = pd.read_excel(ISSUANCE_FILE)
import_df = pd.read_excel(IMPORT_FILE, header=2)
# Out:
# c:\Users\hp\Desktop\internship\project\venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
print(purchase_df.columns)
print(stock_df.columns)
print(issuance_df.columns)
print(list(import_df.columns)[1:])
# Out:
# Index(['Record No', 'Ref No', 'Branch', 'Item Code', 'Item Name',
#        'Specificati', 'UOM', 'Material', 'Standard', 'Qty', 'Weight', ' Price',
#        'Bill No', 'Amount', 'Supplier', 'PPC/Store ', 'Required D',
#        'Lead Time', 'Lead Time2', 'Purchase ', 'Lead Time3', 'MOP', 'DC No',
#        'Pass Qty', 'Weight4', 'PO Numbe', 'Item Categ', 'Sourcing O',
#        'PO Date'],
#       dtype='str')
# Index(['ItemCode', 'Item', 'Category', 'Reorder Level', 'Hold Qty', 'StockQty',
#        'Stock Qty Amou', 'Available Qty', 'Available Amoun', 'Weight(Kgs)',
#        'Branch'],
#       dtype='str')
# Index(['IssuanceCode', 'Branch', 'Department', 'IssueToOthers', 'AuthorizedBy',
#        'IssuedBy', 'ReceivedBy', 'Description', 'RefNo', 'Demand RefN', 'Item',
#        'Specification', 'GroupName', 'MaterialStandard', 'UOM', 'ItemCode',
#        'Material', 'Quantity', 'Weight', 'Status', 'FromDate', 'UnitPrice',
# ...
